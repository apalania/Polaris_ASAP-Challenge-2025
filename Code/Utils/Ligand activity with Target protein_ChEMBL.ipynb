# %% [markdown]
# ### Overview
# #### Downloading Activity data for Ligand inhibitors of Target proteins
#
# 1. Download the ChEMBL database
# 2. Query ChEMBL for drug data
# 3. Remove duplicates from the ChEMBL data

# %% [markdown]
# Install the necessary Python libraries

# %%
# !pip install pandas rdkit tqdm useful_rdkit_utils seaborn scikit-posthocs chembl_downloader
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: rdkit in /usr/local/lib/python3.11/dist-packages (2024.9.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (4.67.1)
# Requirement already satisfied: useful_rdkit_utils in /usr/local/lib/python3.11/dist-packages (0.80)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.11/dist-packages (0.13.2)
# Requirement already satisfied: scikit-posthocs in /usr/local/lib/python3.11/dist-packages (0.11.3)
# Requirement already satisfied: chembl_downloader in /usr/local/lib/python3.11/dist-packages (0.5.1)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.1)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from rdkit) (11.1.0)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from useful_rdkit_utils) (8.1.8)
# Requirement already satisfied: dataclasses in /usr/local/lib/python3.11/dist-packages (from useful_rdkit_utils) (0.6)
# Requirement already satisfied: py3dmol in /usr/local/lib/python3.11/dist-packages (from useful_rdkit_utils) (2.4.2)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.11/dist-packages (from useful_rdkit_utils) (18.1.0)
# Requirement already satisfied: pystow in /usr/local/lib/python3.11/dist-packages (from useful_rdkit_utils) (0.7.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from useful_rdkit_utils) (1.6.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from useful_rdkit_utils) (1.14.1)
# Requirement already satisfied: umap-learn in /usr/local/lib/python3.11/dist-packages (from useful_rdkit_utils) (0.5.7)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /usr/local/lib/python3.11/dist-packages (from seaborn) (3.10.0)
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.11/dist-packages (from scikit-posthocs) (0.14.4)
# Requirement already satisfied: more-click in /usr/local/lib/python3.11/dist-packages (from chembl_downloader) (0.1.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.11/dist-packages (from chembl_downloader) (4.12.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from pystow->useful_rdkit_utils) (2.32.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->useful_rdkit_utils) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->useful_rdkit_utils) (3.6.0)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.11/dist-packages (from statsmodels->scikit-posthocs) (1.0.1)
# Requirement already satisfied: numba>=0.51.2 in /usr/local/lib/python3.11/dist-packages (from umap-learn->useful_rdkit_utils) (0.60.0)
# Requirement already satisfied: pynndescent>=0.5 in /usr/local/lib/python3.11/dist-packages (from umap-learn->useful_rdkit_utils) (0.5.13)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.51.2->umap-learn->useful_rdkit_utils) (0.43.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->pystow->useful_rdkit_utils) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->pystow->useful_rdkit_utils) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->pystow->useful_rdkit_utils) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->pystow->useful_rdkit_utils) (2025.1.31)

# %%
import re

import chembl_downloader
import pandas as pd
import scikit_posthocs as sp
import seaborn as sns
import useful_rdkit_utils as uru
from rdkit import Chem
from rdkit.Chem.Draw import MolsToGridImage
from rdkit.Chem.MolStandardize import rdMolStandardize
from rdkit.rdBase import BlockLogs
from tqdm.auto import tqdm

# %% [markdown]
# Enable progress bars in Pandas

# %%
tqdm.pandas()

# %% [markdown]
# ### 1. Download the ChEMBL database

# %% [markdown]
# [ChEMBL downloader](https://github.com/cthoyt/chembl-downloader) by Charles Tapley Hoyt

# %%
path = chembl_downloader.download_extract_sqlite()
# Out:
# Downloading chembl_35_sqlite.tar.gz: 0.00B [00:00, ?B/s]

# %%
path
# Out:
# PosixPath('/root/.data/chembl/35/data/chembl_35/chembl_35_sqlite/chembl_35.db')

# %% [markdown]
# Define SQL to extract drug data from ChEMBL. It would probably be useful to explain the query below.  We're joining three tables:
# - molecule_dictionary - Table storing a non-redundant list of curated compounds for ChEMBL (includes preclinical compounds, drugs and clinical candidate drugs) and some associated attributes.
# - compound_structures - Table storing various structure representations (e.g., Molfile, InChI) for each compound
# - compound properties - Table storing calculated physicochemical properties for compounds, now calculated with RDKit and ChemAxon software

# %%
sql="""SELECT
    cs.canonical_smiles,
    md.molregno,
    md.pref_name,
    act.standard_type,
    act.standard_value,
    act.standard_units,
    act.pchembl_value,
    t.pref_name AS target_name,
    t.target_type,
    t.chembl_id AS target_chembl_id
FROM
    molecule_dictionary md
JOIN
    compound_structures cs ON md.molregno = cs.molregno
JOIN
    activities act ON md.molregno = act.molregno
JOIN
    assays a ON act.assay_id = a.assay_id
JOIN
    target_dictionary t ON a.tid = t.tid
WHERE
    md.max_phase = 4
    AND md.molecule_type = 'Small molecule'
    AND act.standard_type IN ('IC50')"""

# %%
df = chembl_downloader.query(sql)

# %%
df
# Out:
#                                          canonical_smiles  molregno  \
# 0       Cc1cn([C@H]2C[C@H](N=[N+]=[N-])[C@@H](CO)O2)c(...     27307
# 1       Cc1cn([C@H]2C[C@H](N=[N+]=[N-])[C@@H](CO)O2)c(...     27307
# 2       Cc1cn([C@H]2C[C@H](N=[N+]=[N-])[C@@H](CO)O2)c(...     27307
# 3       Cc1cn([C@H]2C[C@H](N=[N+]=[N-])[C@@H](CO)O2)c(...     27307
# 4       Cc1cn([C@H]2C[C@H](N=[N+]=[N-])[C@@H](CO)O2)c(...     27307
# ...                                                   ...       ...
# 202921  [2H]C([2H])([2H])NC(=O)c1nnc(NC(=O)C2CC2)cc1Nc...   2342179
# 202922  [2H]C([2H])([2H])NC(=O)c1nnc(NC(=O)C2CC2)cc1Nc...   2342179
# 202923  [2H]C([2H])([2H])NC(=O)c1nnc(NC(=O)C2CC2)cc1Nc...   2342179
# 202924  [2H]C([2H])([2H])NC(=O)c1nnc(NC(=O)C2CC2)cc1Nc...   2342179
# 202925  [2H]C([2H])([2H])NC(=O)c1nnc(NC(=O)C2CC2)cc1Nc...   2342179
#
#               pref_name standard_type  standard_value standard_units  \
# 0            ZIDOVUDINE          IC50             4.0             nM
# 1            ZIDOVUDINE          IC50           150.0             nM
# 2            ZIDOVUDINE          IC50             6.0             nM
# 3            ZIDOVUDINE          IC50             4.0             nM
# 4            ZIDOVUDINE          IC50             NaN             nM
# ...                 ...           ...             ...            ...
# 202921  DEUCRAVACITINIB          IC50           592.0             nM
# 202922  DEUCRAVACITINIB          IC50          1900.0             nM
# 202923  DEUCRAVACITINIB          IC50         10000.0             nM
# 202924  DEUCRAVACITINIB          IC50             0.2             nM
# 202925  DEUCRAVACITINIB          IC50           193.0             nM
#
#         pchembl_value                                        target_name  \
# 0                8.40                                              ADMET
# 1                6.82                                              ADMET
# 2                8.22                                              ADMET
# 3                8.40                                              ADMET
# 4                 NaN  Human immunodeficiency virus type 1 reverse tr...
# ...               ...                                                ...
# 202921           6.23                       Tyrosine-protein kinase JAK3
# 202922           5.72                       Tyrosine-protein kinase JAK3
# 202923            NaN                       Tyrosine-protein kinase TYK2
# 202924           9.70                       Tyrosine-protein kinase TYK2
# 202925           6.71         Bone morphogenetic protein receptor type-2
#
#            target_type target_chembl_id
# 0                ADMET     CHEMBL612558
# 1                ADMET     CHEMBL612558
# 2                ADMET     CHEMBL612558
# 3                ADMET     CHEMBL612558
# 4       SINGLE PROTEIN        CHEMBL247
# ...                ...              ...
# 202921  SINGLE PROTEIN       CHEMBL2148
# 202922  SINGLE PROTEIN       CHEMBL2148
# 202923  SINGLE PROTEIN       CHEMBL3553
# 202924  SINGLE PROTEIN       CHEMBL3553
# 202925  SINGLE PROTEIN       CHEMBL5467
#
# [202926 rows x 10 columns]

# %%
df.to_csv('chembl.csv', index=False)
from google.colab import files
files.download('chembl.csv')
